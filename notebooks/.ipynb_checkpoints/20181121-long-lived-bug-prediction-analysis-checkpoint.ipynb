# %% [markdown]
# # Predicting Long-Lived Bugs

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# This first experiment used a dataset with 7935 bug reports extracted from Eclipse Bugzilla Tracking System. The table below shows the evaluation performance metrics yielded.

# %%
import pandas as pd
import numpy as np
results = pd.read_csv('~/Workspace/issue-crawler/rscripts/results/20181117131943-long_live_bug-evaluation.csv')

# filling missing data
results['Acc_1'] = results.Acc_1.fillna(0)
results['Balanced_Acc'] = results.Balanced_Acc.fillna(results.Acc_0 / 2)

# updating data 
results.loc[results['Model'] == 'knn', 'Model'] = 'KNN'
results.loc[results['Model'] == 'rf', 'Model']  = 'Random Forest'
results.loc[results['Model'] == 'svm', 'Model'] = 'SVM'
features = ['Description','Description_Summary']
results = results[results.Feature.isin(features)]
results
# Out:
#      Dataset Model Resampling  Threshold  Train_Size  Train_Qt_Class_0  \
# 0    Eclipse   KNN  bootstrap          4        5804              2511
# 1    Eclipse   KNN  bootstrap          8        5803              3075
# 2    Eclipse   KNN  bootstrap         12        5803              3318
# 3    Eclipse   KNN  bootstrap         16        5803              3555
# 4    Eclipse   KNN  bootstrap         20        5804              3702
# 5    Eclipse   KNN  bootstrap         24        5804              3861
# 6    Eclipse   KNN  bootstrap         28        5804              3977
# 7    Eclipse   KNN  bootstrap         32        5804              4085
# 8    Eclipse   KNN  bootstrap         64        5803              4612
# 9    Eclipse   KNN  bootstrap         96        5803              4867
# 10   Eclipse   KNN  bootstrap        128        5803              5055
# 11   Eclipse   KNN  bootstrap        160        5803              5181
# 12   Eclipse   KNN  bootstrap        192        5804              5268
# 13   Eclipse   KNN  bootstrap        224        5804              5367
# 14   Eclipse   KNN  bootstrap        256        5804              5429
# 15   Eclipse   KNN  bootstrap        288        5803              5475
# 16   Eclipse   KNN  bootstrap        320        5803              5521
# 17   Eclipse   KNN  bootstrap        352        5804              5571
# 18   Eclipse   KNN  bootstrap        384        5803              5607
# 19   Eclipse   KNN  bootstrap        416        5803              5635
# 20   Eclipse   KNN  bootstrap        448        5804              5667
# 21   Eclipse   KNN  bootstrap        480        5803              5683
# 22   Eclipse   KNN  bootstrap        512        5804              5697
# 23   Eclipse   KNN       cv52          4        5804              2511
# 24   Eclipse   KNN       cv52          8        5803              3075
# 25   Eclipse   KNN       cv52         12        5803              3318
# 26   Eclipse   KNN       cv52         16        5803              3555
# 27   Eclipse   KNN       cv52         20        5804              3702
# 28   Eclipse   KNN       cv52         24        5804              3861
# 29   Eclipse   KNN       cv52         28        5804              3977
# ..       ...   ...        ...        ...         ...               ...
# 246  Eclipse   SVM  bootstrap        320        5952              5667
# 247  Eclipse   SVM  bootstrap        352        5952              5717
# 248  Eclipse   SVM  bootstrap        384        5952              5754
# 249  Eclipse   SVM  bootstrap        416        5952              5782
# 250  Eclipse   SVM  bootstrap        448        5952              5814
# 251  Eclipse   SVM  bootstrap        480        5952              5830
# 252  Eclipse   SVM  bootstrap        512        5952              5844
# 253  Eclipse   SVM       cv52          4        5952              2595
# 254  Eclipse   SVM       cv52          8        5952              3174
# 255  Eclipse   SVM       cv52         12        5952              3423
# 256  Eclipse   SVM       cv52         16        5952              3665
# 257  Eclipse   SVM       cv52         20        5952              3812
# 258  Eclipse   SVM       cv52         24        5952              3977
# 259  Eclipse   SVM       cv52         28        5952              4095
# 260  Eclipse   SVM       cv52         32        5952              4204
# 261  Eclipse   SVM       cv52         64        5952              4740
# 262  Eclipse   SVM       cv52         96        5952              4998
# 263  Eclipse   SVM       cv52        128        5952              5191
# 264  Eclipse   SVM       cv52        160        5952              5319
# 265  Eclipse   SVM       cv52        192        5952              5406
# 266  Eclipse   SVM       cv52        224        5952              5507
# 267  Eclipse   SVM       cv52        256        5952              5571
# 268  Eclipse   SVM       cv52        288        5952              5619
# 269  Eclipse   SVM       cv52        320        5952              5667
# 270  Eclipse   SVM       cv52        352        5952              5717
# 271  Eclipse   SVM       cv52        384        5952              5754
# 272  Eclipse   SVM       cv52        416        5952              5782
# 273  Eclipse   SVM       cv52        448        5952              5814
# 274  Eclipse   SVM       cv52        480        5952              5830
# 275  Eclipse   SVM       cv52        512        5952              5844
#
#      Train_Qt_Class_1  Test_Size  Test_Qt_Class_0  Test_Qt_Class_1    ...     \
# 0                3293       1933              836             1097    ...
# 1                2728       1934             1025              909    ...
# 2                2485       1934             1106              828    ...
# 3                2248       1934             1185              749    ...
# 4                2102       1933             1233              700    ...
# 5                1943       1933             1286              647    ...
# 6                1827       1933             1325              608    ...
# 7                1719       1933             1361              572    ...
# 8                1191       1934             1537              397    ...
# 9                 936       1934             1622              312    ...
# 10                748       1934             1685              249    ...
# 11                622       1934             1727              207    ...
# 12                536       1933             1755              178    ...
# 13                437       1933             1788              145    ...
# 14                375       1933             1809              124    ...
# 15                328       1934             1825              109    ...
# 16                282       1934             1840               94    ...
# 17                233       1933             1856               77    ...
# 18                196       1934             1869               65    ...
# 19                168       1934             1878               56    ...
# 20                137       1933             1888               45    ...
# 21                120       1934             1894               40    ...
# 22                107       1933             1898               35    ...
# 23               3293       1933              836             1097    ...
# 24               2728       1934             1025              909    ...
# 25               2485       1934             1106              828    ...
# 26               2248       1934             1185              749    ...
# 27               2102       1933             1233              700    ...
# 28               1943       1933             1286              647    ...
# 29               1827       1933             1325              608    ...
# ..                ...        ...              ...              ...    ...
# 246               285       1983             1888               95    ...
# 247               235       1983             1905               78    ...
# 248               198       1983             1917               66    ...
# 249               170       1983             1927               56    ...
# 250               138       1983             1937               46    ...
# 251               122       1983             1943               40    ...
# 252               108       1983             1947               36    ...
# 253              3357       1983              865             1118    ...
# 254              2778       1983             1058              925    ...
# 255              2529       1983             1140              843    ...
# 256              2287       1983             1221              762    ...
# 257              2140       1983             1270              713    ...
# 258              1975       1983             1325              658    ...
# 259              1857       1983             1364              619    ...
# 260              1748       1983             1401              582    ...
# 258  0.996983  0.800727
# 259  0.994879  0.814615
# 260  0.997149  0.827811
# 261  1.000000  0.886581
# 262  1.000000  0.913032
# 263  1.000000  0.931861
# 264  1.000000  0.944089
# 265  1.000000  0.952180
# 266  1.000000  0.961236
# 267  1.000000  0.966918
# 268  1.000000  0.971473
# 269  1.000000  0.975459
# 270  1.000000  0.979938
# 271  1.000000  0.983077
# 272  1.000000  0.985678
# 273  1.000000  0.988265
# 274  1.000000  0.989812
# 275  1.000000  0.990840
#
# [276 rows x 22 columns]

# %% [markdown]
# ## 2. Analysis of Results

# %%
# calculating ratio between classes.
results['Total_Ratio_Class_0'] = (results['Train_Qt_Class_0'] + results['Test_Qt_Class_0']) / (results['Train_Size']+results['Test_Size']) 
results['Total_Ratio_Class_1'] = (results['Train_Qt_Class_1'] + results['Test_Qt_Class_1']) / (results['Train_Size']+results['Test_Size']) 
results['Train_Ratio_Class_0'] = (results['Train_Qt_Class_0']) / (results['Train_Size']) 
results['Train_Ratio_Class_1'] = (results['Train_Qt_Class_1']) / (results['Train_Size']) 
results['Test_Ratio_Class_0']  = (results['Test_Qt_Class_0'])  / (results['Test_Size']) 
results['Test_Ratio_Class_1']  = (results['Test_Qt_Class_1'])  / (results['Test_Size']) 

results.head(10)
# Out:
#    Dataset Model Resampling  Threshold  Train_Size  Train_Qt_Class_0  \
# 0  Eclipse   KNN  bootstrap          4        5804              2511
# 1  Eclipse   KNN  bootstrap          8        5803              3075
# 2  Eclipse   KNN  bootstrap         12        5803              3318
# 3  Eclipse   KNN  bootstrap         16        5803              3555
# 4  Eclipse   KNN  bootstrap         20        5804              3702
# 5  Eclipse   KNN  bootstrap         24        5804              3861
# 6  Eclipse   KNN  bootstrap         28        5804              3977
# 7  Eclipse   KNN  bootstrap         32        5804              4085
# 8  Eclipse   KNN  bootstrap         64        5803              4612
# 9  Eclipse   KNN  bootstrap         96        5803              4867
#
#    Train_Qt_Class_1  Test_Size  Test_Qt_Class_0  Test_Qt_Class_1  \
# 0              3293       1933              836             1097
# 1              2728       1934             1025              909
# 2              2485       1934             1106              828
# 3              2248       1934             1185              749
# 4              2102       1933             1233              700
# 5              1943       1933             1286              647
# 6              1827       1933             1325              608
# 7              1719       1933             1361              572
# 8              1191       1934             1537              397
# 9               936       1934             1622              312
#
#           ...         Balanced_Acc  Precision    Recall  Fmeasure  \
# 0         ...             0.438661   0.454849  0.260786  0.331505
# 1         ...             0.528320   0.551060  0.563547  0.557233
# 2         ...             0.567130   0.597496  0.638623  0.617375
# 3         ...             0.601410   0.635587  0.744991  0.685954
# 4         ...             0.628635   0.649462  0.811101  0.721338
# 5         ...             0.663364   0.666454  0.893926  0.763610
# 6         ...             0.672268   0.694661  0.884743  0.778264
# 7         ...             0.702693   0.704532  0.944751  0.807148
# 8         ...             0.782331   0.795430  0.992048  0.882925
# 9         ...             0.754720   0.842774  0.990666  0.910755
#
#    Total_Ratio_Class_0  Total_Ratio_Class_1  Train_Ratio_Class_0  \
# 0             0.432597             0.567403             0.432633
# 1             0.529921             0.470079             0.529898
# 2             0.571798             0.428202             0.571773
# 3             0.612641             0.387359             0.612614
# 4             0.637844             0.362156             0.637836
# 5             0.665245             0.334755             0.665231
# 6             0.685279             0.314721             0.685217
# 7             0.703890             0.296110             0.703825
# 8             0.794752             0.205248             0.794761
# 9             0.838697             0.161303             0.838704
#
#    Train_Ratio_Class_1  Test_Ratio_Class_0  Test_Ratio_Class_1
# 0             0.567367            0.432488            0.567512
# 1             0.470102            0.529990            0.470010
# 2             0.428227            0.571872            0.428128
# 3             0.387386            0.612720            0.387280
# 4             0.362164            0.637869            0.362131
# 5             0.334769            0.665287            0.334713
# 6             0.314783            0.685463            0.314537
# 7             0.296175            0.704087            0.295913
# 8             0.205239            0.794726            0.205274
# 9             0.161296            0.838676            0.161324
#
# [10 rows x 28 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
   
def plot_line_by_models(data, title, feature, value, ylabel):
    plt.style.use('default')
    
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20,8), sharex=True)
    all_results = data[data['Feature'] == feature]
    
    bs_results  = all_results[all_results['Resampling'] == 'bootstrap']
    bs_results  = bs_results.pivot_table(index=['Threshold'], columns='Model', values=value)
    
    cv_results  = all_results[all_results['Resampling'] == 'cv52']
    cv_results  = cv_results.pivot_table(index=['Threshold'], columns='Model', values=value)
    
    threshold_range_1 = range(4, 36, 4)
    threshold_range_2 = range(64, 534, 32)
    threshold_range   = list(threshold_range_1) + list(threshold_range_2)
    
    # Setting the figure's main title to the text passed as parameter
    fig.suptitle(title)

    # Plotting for bootstrap resampling
    ax = bs_results.plot(style=['r*-','bo-','y^-']
                        , title = 'resampling: booststrap'
                        #, xticks=threshold_range
                        , yticks=np.arange(0, 1, step=0.1)
                        , grid=True
                        , ax = axes[0]
                        , figsize=(20,8))

    ax.set_ylabel(ylabel)
    ax.set_ylim(0,1.0)
    #ax.set_xticklabels(threshold_range, fontsize=9)
     
    # Plotting for repeated cv 5 x 2 resampling    
    ax = cv_results.plot(style=['r*-','bo-','y^-']
                        , title = 'resampling: cv 5x2'
                        #, xticks=[4, 8, 16, 32, 64, 128, 256, 512]
                        , yticks=np.arange(0, 1, step=0.1)
                        , grid=True
                        , ax = axes[1]
                        , figsize=(20,8))
    
    ax.set_ylabel(ylabel)
    ax.set_ylim(0,1.0)
    
    #ax.set_xticklabels(threshold_range, fontsize=9)
    
    return fig, ax

# %% [markdown]
# ## Analysis Using Description Feature

# %%
plot_line_by_models(results, 'Predicting Long-Lived Bug Using Description', 'Description','Balanced_Acc', 'Balanced Accuracy')
plot_line_by_models(results, '', 'Description',  'Acc_1', 'Accuracy for Long-Lived Bug (True)')
# Out:
# (<Figure size 2000x800 with 2 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x118fcb2b0>)

# %% [markdown]
# Taking into account a reasonable threshold of up to 32 days, the **knn model** yielded the best accuracy value (**70.2%**) for both bootstrap and cross-validation.

# %% [markdown]
# Taking into account a reasonable threshold of up to **32 days**, the **random forest** model yielded the best accuracy values, **76.2%** for both bootstrap and **74.2%** for cross-validation resampling methods.

# %% [markdown]
# ## Analysis Using Description and Summary Features

# %%
plot_line_by_models(results, 'Predicting Long-Lived Bug Using Summary+Description', 'Description_Summary', 'Balanced_Acc', 'Balanced Accuracy')
plot_line_by_models(results, '', 'Description_Summary', 'Acc_1', 'Accuracy for Long-Lived Bug (True)')
# Out:
# (<Figure size 2000x800 with 2 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x117d941d0>)

# %%
#plot_line_by_models(results, 'Predicting Long-Lived Bug Using Summary', 'Summary', 'Balanced_Acc', 'Balanced Accuracy')
#plot_line_by_models(results, '', 'Summary', 'Acc_1', 'Accuracy for Long-Lived Bug (True)')

# %% [markdown]
# Taking into account a reasonable threshold of up to **32 days**, the **knn** model yielded the best accuracy values, **70.7**% for bootstrap and **70.6**% for cross-validation resampling methods.

# %%
def plot_line_ratios(data):
    plt.style.use('default')

    
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20,8), sharex=True)
    ratios = results.iloc[0:8, ]
    ratios = ratios[['Threshold','Total_Ratio_Class_0','Total_Ratio_Class_1']]
   
    ratios_class_0  = ratios[['Threshold','Total_Ratio_Class_0']]
    ratios_class_1  = ratios[['Threshold','Total_Ratio_Class_1']]
    
    ratios_class_0.set_index('Threshold', inplace=True, drop=True)
    ratios_class_1.set_index('Threshold', inplace=True, drop=True)
  
    threshold_range_1 = range(4, 36, 4)
    threshold_range_2 = range(64, 534, 32)
    threshold_range   = list(threshold_range_1) + list(threshold_range_2)
    
    fig.suptitle('Class Ration')

    # Plotting for bootstrap resampling
    ax = ratios_class_0.plot(style=['r*-','bo-','y^-']
                        , title = 'resampling: booststrap'
                        #, xticks=[4, 8, 16, 32, 64, 128, 256, 512]
                        , yticks=np.arange(0, 1, step=0.1)
                        , grid=True
                        , ax = axes[0]
                        , figsize=(20,8))

    ax.set_ylabel('ratio')
    ax.set_ylim(0,1.0)
    #ax.set_xticklabels(threshold_range, fontsize=9)
     
    # Plotting for repeated cv 5 x 2 resampling    
    ax = ratios_class_1.plot(style=['r*-','bo-','y^-']
                        , title = 'resampling: cv 5x2'
                        #, xticks=[4, 8, 16, 32, 64, 128, 256, 512]
                        , yticks=np.arange(0, 1, step=0.1)
                        , grid=True
                        , ax = axes[1]
                        , figsize=(20,8))
    
    ax.set_ylabel('')
    ax.set_ylim(0,1.0)
    #ax.set_xticklabels(threshold_range, fontsize=9)
    
    return fig, ax

plot_line_ratios(results)
# Out:
# (<Figure size 2000x800 with 2 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x11897d9b0>)

# %% [markdown]
# # 3. Tasks Assigned at Last  Meeting

# %% [markdown]
# 1. plot class_0/(class_1 + class_0) and class_0/(class_1 + class_0) ratio. (done)
# 2. plot balanced accuracy for class 1 (done)
# 3. run experiments with threshold starting in 4 and incremented by 4. (in progress)
