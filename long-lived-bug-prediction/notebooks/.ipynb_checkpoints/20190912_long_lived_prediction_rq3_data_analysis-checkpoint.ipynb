# %% [markdown]
# # Research Question No. 3

# %% [markdown]
# ## How frequent are, and what are the main characteristics of long-lived bugs in WineHQ project?

# %% [markdown]
# ## Experimental parameters

# %% [markdown]
# | Project                    |         #Reports     |       #Thesholds     |
# |----------------------------|:--------------------:|:--------------------:|
# | Eclipse                    |        10000         |         365          |
# | WineHQ                     |        10000         |         365          |
#
# Every bug which its report have indicated that the number of days to resolve is less than or equal to **threshold fixed** was considered a **non-long lived bug** and that which the number of days to resolve is greater than this threshold was considered as a **long-live bug**.

# %% [markdown]
# ## Step1. Setup experimental environment.

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import matplotlib.pyplot as plt 
import numpy as np
import os 
import pandas as pd
import seaborn as sns 

# Setup Matplotlib
plt.rc('figure', figsize=(20, 20))
plt.style.use('default')
# %matplotlib inline 

# Setup Seaborn
sns.set_context("paper")
sns.set_style("ticks")

metrics_e1_path = "datasets/20190918180550_rq3e1_eclipse_predict_long_lived_metrics.csv"
print("Setup complete")
# Out:
# Setup complete

# %% [markdown]
# ## Step 2. Load data.

# %%
    # !echo "\nHeader of metrics file $metrics_e1_path"
    # !head -n 2 $metrics_e1_path

    # !echo "\nNumber of lines in the file $metrics_e1_path"
    # !wc -l $metrics_e1_path
# Out:
# Header of metrics file datasets/20190918180550_rq3e1_eclipse_predict_long_lived_metrics.csv
# project,feature,n_term,classifier,balancing,resampling,metric,threshold,train_size,train_size_class_0,train_size_class_1,test_size,test_size_class_0,test_size_class_1,tp,fp,tn,fn,sensitivity,specificity,balanced_acc,balanced_acc_manual,precision,recall,fmeasure
# eclipse,long_description,100,knn,smote,repeatedcv,Accuracy,365,12847,6665,6182,2408,2221,187,85,950,1271,102,0.45454545454545453,0.5722647456100856,0.5134051000777701,0.5134051000777701,0.9257101238164603,0.5722647456100856,0.7072899276572064
#
# Number of lines in the file datasets/20190918180550_rq3e1_eclipse_predict_long_lived_metrics.csv
# 42 datasets/20190918180550_rq3e1_eclipse_predict_long_lived_metrics.csv

# %%
# read metrics data.
metrics_e1_data = pd.read_csv(metrics_e1_path)
rows_and_cols = metrics_e1_data.shape
print(f"There are {rows_and_cols[0]} rows and {rows_and_cols[1]} columns in {metrics_e1_path}.\n")
# Out:
# There are 41 rows and 25 columns in datasets/20190918180550_rq3e1_eclipse_predict_long_lived_metrics.csv.

# %% [markdown]
# ## Step 3. Review the data

# %%
metrics_e1_data.head(42)
# Out:
#     project            feature  n_term classifier   balancing  resampling  \
# 0   eclipse   long_description     100        knn       smote  repeatedcv
# 1   eclipse   long_description     100        knn       smote  repeatedcv
# 2   eclipse   long_description     100        knn       smote  repeatedcv
# 3   eclipse   long_description     100        knn  unbalanced  repeatedcv
# 4   eclipse   long_description     100        knn  unbalanced  repeatedcv
# 5   eclipse   long_description     100        knn  unbalanced  repeatedcv
# 6   eclipse   long_description     100         nb       smote  repeatedcv
# 7   eclipse   long_description     100         nb       smote  repeatedcv
# 8   eclipse   long_description     100         nb       smote  repeatedcv
# 9   eclipse   long_description     100         nb  unbalanced  repeatedcv
# 10  eclipse   long_description     100         nb  unbalanced  repeatedcv
# 11  eclipse   long_description     100         nb  unbalanced  repeatedcv
# 12  eclipse   long_description     100         nn       smote  repeatedcv
# 13  eclipse   long_description     100         nn       smote  repeatedcv
# 14  eclipse   long_description     100         nn       smote  repeatedcv
# 15  eclipse   long_description     100         nn  unbalanced  repeatedcv
# 16  eclipse   long_description     100         nn  unbalanced  repeatedcv
# 17  eclipse   long_description     100         nn  unbalanced  repeatedcv
# 18  eclipse   long_description     100         rf       smote  repeatedcv
# 19  eclipse   long_description     100         rf       smote  repeatedcv
# 20  eclipse   long_description     100         rf       smote  repeatedcv
# 21  eclipse   long_description     100         rf  unbalanced  repeatedcv
# 22  eclipse   long_description     100         rf  unbalanced  repeatedcv
# 23  eclipse   long_description     100         rf  unbalanced  repeatedcv
# 24  eclipse   long_description     100        svm       smote  repeatedcv
# 25  eclipse   long_description     100        svm       smote  repeatedcv
# 26  eclipse   long_description     100        svm       smote  repeatedcv
# 27  eclipse   long_description     100        svm  unbalanced  repeatedcv
# 28  eclipse   long_description     100        svm  unbalanced  repeatedcv
# 29  eclipse   long_description     100        svm  unbalanced  repeatedcv
# 30  eclipse  short_description     100        knn       smote  repeatedcv
# 31  eclipse  short_description     100        knn       smote  repeatedcv
# 32  eclipse  short_description     100        knn       smote  repeatedcv
# 33  eclipse  short_description     100        knn  unbalanced  repeatedcv
# 34  eclipse  short_description     100        knn  unbalanced  repeatedcv
# 35  eclipse  short_description     100        knn  unbalanced  repeatedcv
# 36  eclipse  short_description     100         nb       smote  repeatedcv
# 37  eclipse  short_description     100         nb       smote  repeatedcv
# 38  eclipse  short_description     100         nb       smote  repeatedcv
# 39  eclipse  short_description     100         nb  unbalanced  repeatedcv
# 40  eclipse  short_description     100         nb  unbalanced  repeatedcv
#
#       metric  threshold  train_size  train_size_class_0  ...    fp    tn   fn  \
# 0   Accuracy        365       12847                6665  ...   950  1271  102
# 1      Kappa        365       12847                6665  ...   950  1271  102
# 2        ROC        365       12847                6665  ...  1227   994   75
# 3   Accuracy        365        7227                6665  ...     0  2221  187
# 4      Kappa        365        7227                6665  ...     0  2221  187
# 5        ROC        365        7227                6665  ...     0  2221  187
# 6   Accuracy        365       12847                6665  ...  1165  1056   84
# 7      Kappa        365       12847                6665  ...  1165  1056   84
# 8        ROC        365       12847                6665  ...  1165  1056   84
# 9   Accuracy        365        7227                6665  ...     0  2221  187
# 10     Kappa        365        7227                6665  ...  1313   908   67
# 11       ROC        365        7227                6665  ...  1313   908   67
# 12  Accuracy        365       12847                6665  ...   656  1565  116
# 13     Kappa        365       12847                6665  ...   656  1565  116
# 14       ROC        365       12847                6665  ...   696  1525  117
# 15  Accuracy        365        7227                6665  ...     0  2221  187
# 16     Kappa        365        7227                6665  ...     0  2221  187
# 17       ROC        365        7227                6665  ...     0  2221  187
# 18  Accuracy        365       12847                6665  ...   102  2119  167
# 19     Kappa        365       12847                6665  ...   102  2119  167
# 20       ROC        365       12847                6665  ...   114  2107  171
# 21  Accuracy        365        7227                6665  ...     5  2216  186
# 22     Kappa        365        7227                6665  ...    15  2206  184
# 23       ROC        365        7227                6665  ...    12  2209  184
# 24  Accuracy        365       12847                6665  ...    84  2137  176
# 25     Kappa        365       12847                6665  ...    84  2137  176
# 26       ROC        365       12847                6665  ...    37  2184  182
# 27  Accuracy        365        7227                6665  ...     0  2221  187
# 28     Kappa        365        7227                6665  ...     2  2219  187
# 29       ROC        365        7227                6665  ...     0  2221  187
# 30  Accuracy        365       11225                5846  ...   434  1514  125
# 31     Kappa        365       11225                5846  ...   434  1514  125
# 12  0.704638  0.802153
# 13  0.704638  0.802153
# 14  0.686628  0.789542
# 15  1.000000  0.959603
# 16  1.000000  0.959603
# 17  1.000000  0.959603
# 18  0.954075  0.940315
# 19  0.954075  0.940315
# 20  0.948672  0.936653
# 21  0.997749  0.958685
# 22  0.993246  0.956842
# 23  0.994597  0.957521
# 24  0.962179  0.942655
# 25  0.962179  0.942655
# 26  0.983341  0.952256
# 27  1.000000  0.959603
# 28  0.999100  0.959153
# 29  1.000000  0.959603
# 30  0.777207  0.844159
# 31  0.777207  0.844159
# 32  0.775667  0.843192
# 33  1.000000  0.960079
# 34  0.996920  0.959012
# 35  1.000000  0.960079
# 36  0.440452  0.597909
# 37  0.440452  0.597909
# 38  0.016427  0.032274
# 39  0.998973  0.959566
# 40  0.451745  0.609418
#
# [41 rows x 25 columns]

# %%
metrics_e1_data[['sensitivity', 'specificity', 'balanced_acc', 'precision', 'recall', 'fmeasure']].describe()
# Out:
#        sensitivity  specificity  balanced_acc  precision     recall   fmeasure
# count    41.000000    41.000000     41.000000  41.000000  41.000000  41.000000
# mean      0.233594     0.789177      0.511386   0.925157   0.789177   0.823548
# std       0.273110     0.259797      0.013270   0.003904   0.259797   0.193325
# min       0.000000     0.016427      0.498954   0.914286   0.016427   0.032274
# 25%       0.000000     0.572265      0.500000   0.922342   0.572265   0.707290
# 50%       0.085561     0.954075      0.505039   0.923734   0.954075   0.940315
# 75%       0.454545     1.000000      0.522695   0.926947   1.000000   0.959603
# max       0.981481     1.000000      0.542158   0.936170   1.000000   0.960079

# %%
sns.despine(offset=5)
sns.set(style="whitegrid")
g = sns.catplot(data=metrics_e1_data
                , kind="bar"
                , x="classifier"
                , y="balanced_acc"
                , hue="metric"
                , col="balancing"
                , saturation=.5
                , height=6
                , palette="muted")
(g.set_axis_labels("", "Balanced Accuracy")
  .set_titles(" {col_var}: {col_name}")
  .set(yticks=np.arange(0, 1.1, 0.1))
  .set(ylim=(0, 1))
  .despine(left=True))

# %%
sns.despine(offset=5)
sns.set(style="whitegrid")
#g = sns.FacetGrid(metrics_e1_data, col="balancing", despine=True)
g = sns.catplot(data=metrics_e1_data
                , kind="bar"
                , x="classifier"
                , y="sensitivity"
                , hue="metric"
                , col="balancing"
                , saturation=.5
                , height=6
                , palette="muted")
(g.set_axis_labels("", "Sensitivity")
  .set_titles(" {col_var}: {col_name}")
  .set(ylim=(0, 1))
  .despine(left=True))

# %%
sns.despine(offset=5)
sns.set(style="whitegrid")
#g = sns.FacetGrid(metrics_e1_data, col="balancing", despine=True)
g = sns.catplot(data=metrics_e1_data
                , kind="bar"
                , x="classifier"
                , y="specificity"
                , hue="metric"
                , col="balancing"
                , saturation=.5
                , height=6
                , palette="muted")
(g.set_axis_labels("", "Specificity")
  .set_titles(" {col_var}: {col_name}")
  .set(ylim=(0, 1))
  .despine(left=True))

# %%
sns.despine(offset=5)
sns.set(style="whitegrid")
#g = sns.FacetGrid(metrics_e1_data, col="balancing", despine=True)
g = sns.catplot(data=metrics_e1_data
                , kind="bar"
                , x="classifier"
                , y="fmeasure"
                , hue="metric"
                , col="balancing"
                , saturation=.5
                , height=6
                , palette="muted")
(g.set_axis_labels("", "Balanced Accuracy")
  .set_titles(" {col_var}: {col_name}")
  .set(ylim=(0, 1))
  .despine(left=True))
