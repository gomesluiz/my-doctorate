# %% [markdown]
# # Long-lived Bug Prediction with Deep Learning

# %% [markdown]
# # 1. Setup environment.

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import matplotlib.pyplot as plt 
import numpy as np
import os 
import pandas as pd
import seaborn as sns 
from scipy.stats import friedmanchisquare
from scipy.stats import kruskal

# %matplotlib inline 

pd.set_option('display.max_columns', None)

#data_evaluation_path  = "../../data/processed/20200516212507-long-lived-bug-prediction-w-dnn-results.csv"
eclipse_data_evaluation_path  = "../../data/processed/20200521131944-long-lived-bug-prediction-w-dnn-results.csv"
freedesktop_data_evaluation_path  = "../../data/processed/20200520013110-long-lived-bug-prediction-w-dnn-results.csv"
gcc_data_evaluation_path  = "../../data/processed/20200520202905-long-lived-bug-prediction-w-dnn-results.csv"
gnome_data_evaluation_path  = "../../data/processed/20200522123241-long-lived-bug-prediction-w-dnn-results.csv"
mozilla_data_evaluation_path  = "../../data/processed/20200523234748-long-lived-bug-prediction-w-dnn-results.csv"
winehq_data_evaluation_path  = "../../data/processed/20200525022852-long-lived-bug-prediction-w-dnn-results.csv"

print("Setup complete")
# Out:
# Setup complete

# %% [markdown]
# # 2. Load data.

# %%
# !echo "\nHeader of metrics file $eclipse_data_evaluation_path"
# !head -n 2 $eclipse_data_evaluation_path
# !echo "\nNumber of lines in the file $eclipse_data_evaluation_path"
# !wc -l $eclipse_data_evaluation_path

# !echo "\nHeader of metrics file $freedesktop_data_evaluation_path"
# !head -n 2 $freedesktop_data_evaluation_path
# !echo "\nNumber of lines in the file $freedesktop_data_evaluation_path"
# !wc -l $freedesktop_data_evaluation_path

# !echo "\nHeader of metrics file $gcc_data_evaluation_path"
# !head -n 2 $gcc_data_evaluation_path
# !echo "\nNumber of lines in the file $gcc_data_evaluation_path"
# !wc -l $gcc_data_evaluation_path

# !echo "\nHeader of metrics file $gnome_data_evaluation_path"
# !head -n 2 $gnome_data_evaluation_path
# !echo "\nNumber of lines in the file $gnome_data_evaluation_path"
# !wc -l $gnome_data_evaluation_path

# !echo "\nHeader of metrics file $mozilla_data_evaluation_path"
# !head -n 2 $mozilla_data_evaluation_path
# !echo "\nNumber of lines in the file $mozilla_data_evaluation_path"
# !wc -l $mozilla_data_evaluation_path

# !echo "\nHeader of metrics file $winehq_data_evaluation_path"
# !head -n 2 $winehq_data_evaluation_path
# !echo "\nNumber of lines in the file $winehq_data_evaluation_path"
# !wc -l $winehq_data_evaluation_path
# Out:
# \nHeader of metrics file ../../data/processed/20200521131944-long-lived-bug-prediction-w-dnn-results.csv
# #,project,feature,classifier,balancing,resampling,metric,threshold,terms,train_size,train_size_class_0,train_size_class_1,val_size,val_size_class_0,val_size_class_1,test_size,test_size_class_0,test_size_class_1,loss,tp,fp,tn,fn,accuracy,precision,recall,auc,sensitivity,specificity,balanced_acc,fmeasure,epochs
# 0,eclipse,long_description,lstm+emb,smote,repeated_cv_5x2,val_accuracy,8,100,5880,2940,2940,1470,735,735,2444,1225,1219,0.6904810070991516,1314.0,1157.0,1287.0,1130.0,0.5321194529533386,0.5317685008049011,0.5376431941986084,0.5460109710693359,0.5376432078559739,0.526595744680851,0.5342184125495973,0.5346897115165998,200
# \nNumber of lines in the file ../../data/processed/20200521131944-long-lived-bug-prediction-w-dnn-results.csv
# 21 ../../data/processed/20200521131944-long-lived-bug-prediction-w-dnn-results.csv
# \nHeader of metrics file ../../data/processed/20200520013110-long-lived-bug-prediction-w-dnn-results.csv
# #,project,feature,classifier,balancing,resampling,metric,threshold,terms,train_size,train_size_class_0,train_size_class_1,val_size,val_size_class_0,val_size_class_1,test_size,test_size_class_0,test_size_class_1,loss,tp,fp,tn,fn,accuracy,precision,recall,auc,sensitivity,specificity,balanced_acc,fmeasure,epochs
# 0,freedesktop,long_description,lstm+emb,smote,repeated_cv_5x2,val_accuracy,28,100,4628,2314,2314,1156,578,578,1915,963,952,0.6919946670532227,1027.0,910.0,1005.0,888.0,0.5305482745170593,0.5302013158798218,0.5362924337387085,0.5461105108261108,0.5362924281984334,0.5248041775456919,0.5295246603314223,0.5332294805597516,200
# \nNumber of lines in the file ../../data/processed/20200520013110-long-lived-bug-prediction-w-dnn-results.csv
# 21 ../../data/processed/20200520013110-long-lived-bug-prediction-w-dnn-results.csv
# \nHeader of metrics file ../../data/processed/20200520202905-long-lived-bug-prediction-w-dnn-results.csv
# #,project,feature,classifier,balancing,resampling,metric,threshold,terms,train_size,train_size_class_0,train_size_class_1,val_size,val_size_class_0,val_size_class_1,test_size,test_size_class_0,test_size_class_1,loss,tp,fp,tn,fn,accuracy,precision,recall,auc,sensitivity,specificity,balanced_acc,fmeasure,epochs
# 0,gcc,long_description,lstm+emb,smote,repeated_cv_5x2,val_accuracy,63,100,5991,2996,2995,1497,748,749,2489,1247,1242,0.7403581738471985,1232.0,1254.0,1235.0,1257.0,0.4955805540084839,0.4955752193927765,0.4949778914451599,0.4966208338737488,0.49497790277219766,0.4961832061068702,0.49418927487160813,0.4952763753172285,200
# \nNumber of lines in the file ../../data/processed/20200520202905-long-lived-bug-prediction-w-dnn-results.csv
# 21 ../../data/processed/20200520202905-long-lived-bug-prediction-w-dnn-results.csv
# \nHeader of metrics file ../../data/processed/20200522123241-long-lived-bug-prediction-w-dnn-results.csv
# #,project,feature,classifier,balancing,resampling,metric,threshold,terms,train_size,train_size_class_0,train_size_class_1,val_size,val_size_class_0,val_size_class_1,test_size,test_size_class_0,test_size_class_1,loss,tp,fp,tn,fn,accuracy,precision,recall,auc,sensitivity,specificity,balanced_acc,fmeasure,epochs
# 0,gnome,long_description,lstm+emb,smote,repeated_cv_5x2,val_accuracy,23,100,4783,2392,2391,1195,597,598,1985,996,989,0.7609260082244873,1053.0,937.0,1048.0,932.0,0.5292191505432129,0.5291457176208496,0.5304785966873169,0.5321497321128845,0.530478589420655,0.5279596977329974,0.5301671803493042,0.5298113188538566,200
# \nNumber of lines in the file ../../data/processed/20200522123241-long-lived-bug-prediction-w-dnn-results.csv
# 21 ../../data/processed/20200522123241-long-lived-bug-prediction-w-dnn-results.csv
# \nHeader of metrics file ../../data/processed/20200523234748-long-lived-bug-prediction-w-dnn-results.csv
# #,project,feature,classifier,balancing,resampling,metric,threshold,terms,train_size,train_size_class_0,train_size_class_1,val_size,val_size_class_0,val_size_class_1,test_size,test_size_class_0,test_size_class_1,loss,tp,fp,tn,fn,accuracy,precision,recall,auc,sensitivity,specificity,balanced_acc,fmeasure,epochs
# 0,mozilla,long_description,lstm+emb,smote,repeated_cv_5x2,val_accuracy,24,100,5888,2944,2944,1472,736,736,2445,1226,1219,0.6900162696838379,1410.0,1065.0,1380.0,1035.0,0.5705521702766418,0.5696969628334045,0.5766870975494385,0.5785609483718872,0.5766871165644172,0.5644171779141104,0.5714559576686156,0.5731707188416579,200
# \nNumber of lines in the file ../../data/processed/20200523234748-long-lived-bug-prediction-w-dnn-results.csv
# 21 ../../data/processed/20200523234748-long-lived-bug-prediction-w-dnn-results.csv
# \nHeader of metrics file ../../data/processed/20200525022852-long-lived-bug-prediction-w-dnn-results.csv
# #,project,feature,classifier,balancing,resampling,metric,threshold,terms,train_size,train_size_class_0,train_size_class_1,val_size,val_size_class_0,val_size_class_1,test_size,test_size_class_0,test_size_class_1,loss,tp,fp,tn,fn,accuracy,precision,recall,auc,sensitivity,specificity,balanced_acc,fmeasure,epochs
# 0,winehq,long_description,lstm+emb,smote,repeated_cv_5x2,val_accuracy,220,100,3639,1819,1820,909,455,454,1514,757,757,0.7120703458786011,745.0,748.0,766.0,769.0,0.49900925159454346,0.498995304107666,0.49207398295402527,0.494249165058136,0.49207397622192867,0.5059445178335535,0.4973579920739762,0.49551047534849085,200
# \nNumber of lines in the file ../../data/processed/20200525022852-long-lived-bug-prediction-w-dnn-results.csv
# 21 ../../data/processed/20200525022852-long-lived-bug-prediction-w-dnn-results.csv

# %%
# read metrics data.
eclipse_data_evaluation = pd.read_csv(eclipse_data_evaluation_path, sep=',', decimal='.')
rows_and_cols = eclipse_data_evaluation.shape
print(f"There are {rows_and_cols[0]} rows and {rows_and_cols[1]} columns in {eclipse_data_evaluation_path}.\n")

freedesktop_data_evaluation = pd.read_csv(freedesktop_data_evaluation_path, sep=',', decimal='.')
rows_and_cols = freedesktop_data_evaluation.shape
print(f"There are {rows_and_cols[0]} rows and {rows_and_cols[1]} columns in {freedesktop_data_evaluation_path}.\n")

gcc_data_evaluation = pd.read_csv(gcc_data_evaluation_path, sep=',', decimal='.')
rows_and_cols = gcc_data_evaluation.shape
print(f"There are {rows_and_cols[0]} rows and {rows_and_cols[1]} columns in {gcc_data_evaluation_path}.\n")

gnome_data_evaluation = pd.read_csv(gnome_data_evaluation_path, sep=',', decimal='.')
rows_and_cols = gnome_data_evaluation.shape
print(f"There are {rows_and_cols[0]} rows and {rows_and_cols[1]} columns in {gnome_data_evaluation_path}.\n")

mozilla_data_evaluation = pd.read_csv(mozilla_data_evaluation_path, sep=',', decimal='.')
rows_and_cols = mozilla_data_evaluation.shape
print(f"There are {rows_and_cols[0]} rows and {rows_and_cols[1]} columns in {mozilla_data_evaluation_path}.\n")

winehq_data_evaluation = pd.read_csv(winehq_data_evaluation_path, sep=',', decimal='.')
rows_and_cols = winehq_data_evaluation.shape
print(f"There are {rows_and_cols[0]} rows and {rows_and_cols[1]} columns in {winehq_data_evaluation_path}.\n")
# Out:
# There are 20 rows and 32 columns in ../../data/processed/20200521131944-long-lived-bug-prediction-w-dnn-results.csv.
#
# There are 20 rows and 32 columns in ../../data/processed/20200520013110-long-lived-bug-prediction-w-dnn-results.csv.
#
# There are 20 rows and 32 columns in ../../data/processed/20200520202905-long-lived-bug-prediction-w-dnn-results.csv.
#
# There are 20 rows and 32 columns in ../../data/processed/20200522123241-long-lived-bug-prediction-w-dnn-results.csv.
#
# There are 20 rows and 32 columns in ../../data/processed/20200523234748-long-lived-bug-prediction-w-dnn-results.csv.
#
# There are 20 rows and 32 columns in ../../data/processed/20200525022852-long-lived-bug-prediction-w-dnn-results.csv.

# %% [markdown]
# # 3. Baseline Experiment

# %% [markdown]
# ## Parameters

# %% [markdown]
# | Parameter                  |         Value        |
# |----------------------------|:--------------------:|
# | Project                    |        Eclipse, Freedesktop, Gcc, Gnome, Mozilla, WineHQ       |
# | Algorithms                 |        lstm+emb |
# | Metrics                    | Accuracy |
# | Features                   | Long Description |
# | Number of Terms            |        100, 150, 200, 250, 300       |
# | Balancing                  |        Smote   |
# | Resampling                 |        Repeated CV 5 x 2       |
# | Threshold                  |                |

# %% [markdown]
# ## 3.1 Review the data

# %% [markdown]
# ### Best Balanced Accuracy Scores

# %%
eclipse_data_evaluation.sort_values('balanced_acc', ascending=False).head()
# Out:
#      #  project           feature classifier balancing       resampling  \
# 8    8  eclipse  long_description   lstm+emb     smote  repeated_cv_5x2
# 16  16  eclipse  long_description   lstm+emb     smote  repeated_cv_5x2
# 0    0  eclipse  long_description   lstm+emb     smote  repeated_cv_5x2
# 12  12  eclipse  long_description   lstm+emb     smote  repeated_cv_5x2
# 17  17  eclipse  long_description   lstm+emb     smote  repeated_cv_5x2
#
#           metric  threshold  terms  train_size  train_size_class_0  \
# 8   val_accuracy          8    200        5880                2940
# 16  val_accuracy          8    300        5880                2940
# 0   val_accuracy          8    100        5880                2940
# 12  val_accuracy          8    250        5880                2940
# 17  val_accuracy         63    300        8802                4401
#
#     train_size_class_1  val_size  val_size_class_0  val_size_class_1  \
# 8                 2940      1470               735               735
# 16                2940      1470               735               735
# 0                 2940      1470               735               735
# 12                2940      1470               735               735
# 17                4401      2200              1100              1100
#
#     test_size  test_size_class_0  test_size_class_1      loss      tp      fp  \
# 8        2444               1225               1219  0.690387  1330.0  1142.0
# 16       2444               1225               1219  0.694026  1317.0  1128.0
# 0        2444               1225               1219  0.690481  1314.0  1157.0
# 12       2444               1225               1219  0.690969  1301.0  1137.0
# 17       2444               1833                611  3.066360  1026.0  1420.0
#
#         tn      fn  accuracy  precision    recall       auc  sensitivity  \
# 8   1302.0  1114.0  0.538462   0.538026  0.544190  0.547478     0.544190
# 16  1316.0  1127.0  0.538666   0.538650  0.538871  0.546026     0.538871
# 0   1287.0  1130.0  0.532119   0.531769  0.537643  0.546011     0.537643
# 12  1307.0  1143.0  0.533552   0.533634  0.532324  0.546509     0.532324
# 17  1024.0  1418.0  0.419394   0.419460  0.419804  0.325692     0.419804
#
#     specificity  balanced_acc  fmeasure  epochs
# 8      0.532733      0.538083  0.541090     200
# 16     0.538462      0.536639  0.538760     200
# 0      0.526596      0.534218  0.534690     200
# 12     0.534779      0.533539  0.532978     200
# 17     0.418985      0.531642  0.419632     200

# %%
freedesktop_data_evaluation.sort_values('balanced_acc', ascending=False).head()
# Out:
#      #      project           feature classifier balancing       resampling  \
# 14  14  freedesktop  long_description   lstm+emb     smote  repeated_cv_5x2
# 4    4  freedesktop  long_description   lstm+emb     smote  repeated_cv_5x2
# 10  10  freedesktop  long_description   lstm+emb     smote  repeated_cv_5x2
# 12  12  freedesktop  long_description   lstm+emb     smote  repeated_cv_5x2
# 0    0  freedesktop  long_description   lstm+emb     smote  repeated_cv_5x2
#
#           metric  threshold  terms  train_size  train_size_class_0  \
# 14  val_accuracy        162    250        6903                3451
# 4   val_accuracy         28    150        4628                2314
# 10  val_accuracy        162    200        6903                3451
# 12  val_accuracy         28    250        4628                2314
# 0   val_accuracy         28    100        4628                2314
#
#     train_size_class_1  val_size  val_size_class_0  val_size_class_1  \
# 14                3452      1725               863               862
# 4                 2314      1156               578               578
# 10                3452      1725               863               862
# 12                2314      1156               578               578
# 0                 2314      1156               578               578
#
#     test_size  test_size_class_0  test_size_class_1      loss      tp      fp  \
# 14       1915               1437                478  1.875083   910.0  1010.0
# 4        1915                963                952  0.721845  1039.0   895.0
# 10       1915               1437                478  1.459191   915.0   998.0
# 12       1915                963                952  0.690815  1008.0   895.0
# 0        1915                963                952  0.691995  1027.0   910.0
#
#         tn      fn  accuracy  precision    recall       auc  sensitivity  \
# 14   905.0  1005.0  0.473890   0.473958  0.475196  0.404467     0.475196
# 4   1020.0   876.0  0.537598   0.537229  0.542559  0.541634     0.542559
# 10   917.0  1000.0  0.478329   0.478306  0.477807  0.410750     0.477807
# 12  1020.0   907.0  0.529504   0.529690  0.526371  0.550635     0.526371
# 0   1005.0   888.0  0.530548   0.530201  0.536292  0.546111     0.536292
#
#     specificity  balanced_acc  fmeasure  epochs
# 14     0.472585      0.540367  0.474576     200
# 4      0.532637      0.540365  0.539880     200
# 10     0.478851      0.535115  0.478056     200
# 12     0.532637      0.529861  0.528025     200
# 0      0.524804      0.529525  0.533229     200

# %%
gcc_data_evaluation.sort_values('balanced_acc', ascending=False).head()
# Out:
#      # project           feature classifier balancing       resampling  \
# 2    2     gcc  long_description   lstm+emb     smote  repeated_cv_5x2
# 6    6     gcc  long_description   lstm+emb     smote  repeated_cv_5x2
# 14  14     gcc  long_description   lstm+emb     smote  repeated_cv_5x2
# 1    1     gcc  long_description   lstm+emb     smote  repeated_cv_5x2
# 15  15     gcc  long_description   lstm+emb     smote  repeated_cv_5x2
#
#           metric  threshold  terms  train_size  train_size_class_0  \
# 2   val_accuracy        475    100        8965                4483
# 6   val_accuracy        475    150        8965                4483
# 14  val_accuracy        475    250        8965                4483
# 1   val_accuracy        337    100        8319                4160
# 15  val_accuracy        365    250        8468                4234
#
#     train_size_class_1  val_size  val_size_class_0  val_size_class_1  \
# 2                 4482      2241              1120              1121
# 6                 4482      2241              1120              1121
# 14                4482      2241              1120              1121
# 1                 4159      2079              1039              1040
# 15                4234      2116              1058              1058
#
#     test_size  test_size_class_0  test_size_class_1      loss      tp      fp  \
# 2        2490               1867                623  2.323232   974.0  1512.0
# 6        2490               1867                623  1.555533  1011.0  1478.0
# 14       2490               1867                623  2.244883   920.0  1560.0
# 1        2489               1732                757  1.057891  1151.0  1343.0
# 15       2489               1763                726  1.297273  1165.0  1352.0
#
#         tn      fn  accuracy  precision    recall       auc  sensitivity  \
# 2    978.0  1516.0  0.391968   0.391794  0.391165  0.338223     0.391165
# 6   1012.0  1479.0  0.406225   0.406187  0.406024  0.366222     0.406024
# 14   930.0  1570.0  0.371486   0.370968  0.369478  0.323224     0.369478
# 1   1146.0  1338.0  0.461430   0.461508  0.462435  0.435221     0.462435
# 15  1137.0  1324.0  0.462435   0.462853  0.468059  0.427706     0.468059
#
#     specificity  balanced_acc  fmeasure  epochs
# 2      0.392771      0.539728  0.391479     200
# 6      0.406426      0.533056  0.406106     200
# 14     0.373494      0.528741  0.370221     200
# 1      0.460426      0.528678  0.461971     200
# 15     0.456810      0.528495  0.465441     200

# %%
gnome_data_evaluation.sort_values('balanced_acc', ascending=False).head()
# Out:
#      # project           feature classifier balancing       resampling  \
# 5    5   gnome  long_description   lstm+emb     smote  repeated_cv_5x2
# 9    9   gnome  long_description   lstm+emb     smote  repeated_cv_5x2
# 13  13   gnome  long_description   lstm+emb     smote  repeated_cv_5x2
# 17  17   gnome  long_description   lstm+emb     smote  repeated_cv_5x2
# 11  11   gnome  long_description   lstm+emb     smote  repeated_cv_5x2
#
#           metric  threshold  terms  train_size  train_size_class_0  \
# 5   val_accuracy        202    150        7468                3734
# 9   val_accuracy        202    200        7468                3734
# 13  val_accuracy        202    250        7468                3734
# 17  val_accuracy        202    300        7468                3734
# 11  val_accuracy        365    200        8156                4078
#
#     train_size_class_1  val_size  val_size_class_0  val_size_class_1  \
# 5                 3734      1866               933               933
# 9                 3734      1866               933               933
# 13                3734      1866               933               933
# 17                3734      1866               933               933
# 11                4078      2038              1019              1019
#
#     test_size  test_size_class_0  test_size_class_1      loss     tp      fp  \
# 5        1985               1555                430  3.280241  826.0  1153.0
# 9        1985               1555                430  3.007644  780.0  1205.0
# 13       1985               1555                430  2.864656  733.0  1251.0
# 17       1985               1555                430  3.733705  733.0  1255.0
# 11       1985               1699                286  4.262142  695.0  1290.0
#
#        tn      fn  accuracy  precision    recall       auc  sensitivity  \
# 5   832.0  1159.0  0.417632   0.417383  0.416121  0.328105     0.416121
# 9   780.0  1205.0  0.392947   0.392947  0.392947  0.299894     0.392947
# 13  734.0  1252.0  0.369521   0.369456  0.369270  0.290579     0.369270
# 17  730.0  1252.0  0.368514   0.368712  0.369270  0.292288     0.369270
# 11  695.0  1290.0  0.350126   0.350126  0.350126  0.231234     0.350126
#
#     specificity  balanced_acc  fmeasure  epochs
# 5      0.419144      0.544938  0.416751     200
# 9      0.392947      0.544201  0.392947     200
# 13     0.369773      0.541509  0.369363     200
# 17     0.367758      0.539183  0.368991     200
# 11     0.350126      0.538943  0.350126     200

# %%
mozilla_data_evaluation.sort_values('balanced_acc', ascending=False).head()
# Out:
#      #  project           feature classifier balancing       resampling  \
# 0    0  mozilla  long_description   lstm+emb     smote  repeated_cv_5x2
# 4    4  mozilla  long_description   lstm+emb     smote  repeated_cv_5x2
# 16  16  mozilla  long_description   lstm+emb     smote  repeated_cv_5x2
# 14  14  mozilla  long_description   lstm+emb     smote  repeated_cv_5x2
# 15  15  mozilla  long_description   lstm+emb     smote  repeated_cv_5x2
#
#           metric  threshold  terms  train_size  train_size_class_0  \
# 0   val_accuracy         24    100        5888                2944
# 4   val_accuracy         24    150        5888                2944
# 16  val_accuracy         24    300        5888                2944
# 14  val_accuracy        188    250        8802                4401
# 15  val_accuracy        365    250        9610                4805
#
#     train_size_class_1  val_size  val_size_class_0  val_size_class_1  \
# 0                 2944      1472               736               736
# 4                 2944      1472               736               736
# 16                2944      1472               736               736
# 14                4401      2200              1100              1100
# 15                4805      2402              1201              1201
#
#     test_size  test_size_class_0  test_size_class_1      loss      tp      fp  \
# 0        2445               1226               1219  0.690016  1410.0  1065.0
# 4        2445               1226               1219  0.698451  1362.0  1093.0
# 16       2445               1226               1219  0.697446  1350.0  1094.0
# 14       2445               1833                612  1.915614  1136.0  1310.0
# 15       2446               2002                444  2.234205  1018.0  1429.0
#
#         tn      fn  accuracy  precision    recall       auc  sensitivity  \
# 0   1380.0  1035.0  0.570552   0.569697  0.576687  0.578561     0.576687
# 4   1352.0  1083.0  0.555010   0.554786  0.557055  0.563570     0.557055
# 16  1351.0  1095.0  0.552352   0.552373  0.552147  0.565205     0.552147
# 14  1135.0  1309.0  0.464417   0.464432  0.464622  0.402912     0.464622
# 15  1017.0  1428.0  0.415985   0.416020  0.416190  0.335992     0.416190
#
#     specificity  balanced_acc  fmeasure  epochs
# 0      0.564417      0.571456  0.573171     200
# 4      0.552965      0.551803  0.555918     200
# 16     0.552556      0.549818  0.552260     200
# 14     0.464213      0.546884  0.464527     200
# 15     0.415781      0.546451  0.416105     200

# %%
winehq_data_evaluation.sort_values('balanced_acc', ascending=False).head()
# Out:
#      # project           feature classifier balancing       resampling  \
# 5    5  winehq  long_description   lstm+emb     smote  repeated_cv_5x2
# 1    1  winehq  long_description   lstm+emb     smote  repeated_cv_5x2
# 18  18  winehq  long_description   lstm+emb     smote  repeated_cv_5x2
# 13  13  winehq  long_description   lstm+emb     smote  repeated_cv_5x2
# 10  10  winehq  long_description   lstm+emb     smote  repeated_cv_5x2
#
#           metric threshold terms  train_size  train_size_class_0  \
# 5   val_accuracy       491   150        4800                2400
# 1   val_accuracy       491   100        4800                2400
# 18  val_accuracy       798   300        5688                2844
# 13  val_accuracy       491   250        4800                2400
# 10  val_accuracy       798   200        5688                2844
#
#     train_size_class_1  val_size  val_size_class_0  val_size_class_1  \
# 5                 2400      1200               600               600
# 1                 2400      1200               600               600
# 18                2844      1422               711               711
# 13                2400      1200               600               600
# 10                2844      1422               711               711
#
#     test_size  test_size_class_0  test_size_class_1      loss     tp     fp  \
# 5        1514                999                515  0.966133  758.0  763.0
# 1        1514                999                515  1.161790  705.0  810.0
# 18       1514               1184                330  2.027029  634.0  864.0
# 13       1514                999                515  1.423369  683.0  836.0
# 10       1514               1184                330  1.995326  615.0  911.0
#
#        tn     fn  accuracy  precision    recall       auc  sensitivity  \
# 5   751.0  756.0  0.498349   0.498356  0.500660  0.470620     0.500661
# 1   704.0  809.0  0.465324   0.465347  0.465654  0.431812     0.465654
# 18  650.0  880.0  0.424042   0.423231  0.418758  0.352940     0.418758
# 13  678.0  831.0  0.449472   0.449638  0.451123  0.422581     0.451123
# 10  603.0  899.0  0.402246   0.403014  0.406209  0.328406     0.406209
#
#     specificity  balanced_acc  fmeasure  epochs
# 5      0.496037      0.537895  0.499506     200
# 1      0.464993      0.525130  0.465500     200
# 18     0.429326      0.525005  0.420983     200
# 13     0.447820      0.524317  0.450379     200
# 10     0.398283      0.523935  0.404605     200

# %%
data_frames = [eclipse_data_evaluation, freedesktop_data_evaluation, gcc_data_evaluation,
                   gnome_data_evaluation, mozilla_data_evaluation, winehq_data_evaluation]

all_data_evaluation = pd.concat(data_frames)

# %% [markdown]
# ## 3.2 Evaluation Metrics

# %% [markdown]
# ### Balanced Accuracy
# Accurácia balanceada: (sensitivity + specificity)/2

# %%
sns.set_context('paper', font_scale = 1.5)
sns.set_style("ticks", {'axes.grid' : False})

eclipse_data_evaluation.threshold = eclipse_data_evaluation['threshold'].astype(str)
eclipse_data_evaluation.terms = eclipse_data_evaluation['terms'].astype(str)
g1 = sns.catplot(data=eclipse_data_evaluation, x="threshold", y="balanced_acc"
                , hue="terms", kind="point", height=6
                , aspect=2, order=['8', '63', '108', '365']
                , col="project")
g1.set(ylim=(0, 0.6))

freedesktop_data_evaluation.threshold = freedesktop_data_evaluation['threshold'].astype(str)
freedesktop_data_evaluation.terms = freedesktop_data_evaluation['terms'].astype(str)
g2 = sns.catplot(data=freedesktop_data_evaluation, x="threshold", y="balanced_acc"
                , hue="terms", kind="point", height=6
                , aspect=2, order=['28', '162', '173', '365']
                , col="project")
g2.set(ylim=(0, 0.6))

gcc_data_evaluation.threshold = gcc_data_evaluation['threshold'].astype(str)
gcc_data_evaluation.terms = gcc_data_evaluation['terms'].astype(str)
g3 = sns.catplot(data=gcc_data_evaluation, x="threshold", y="balanced_acc"
                , hue="terms", kind="point", height=6
                , aspect=2, order=['63', '337', '365', '475']
                , col="project")
g3.set(ylim=(0, 0.6))

gnome_data_evaluation.threshold = gnome_data_evaluation['threshold'].astype(str)
gnome_data_evaluation.terms = gnome_data_evaluation['terms'].astype(str)
g4 = sns.catplot(data=gnome_data_evaluation, x="threshold", y="balanced_acc"
                , hue="terms", kind="point", height=6
                , aspect=2, order=['23', '162', '202', '365']
                , col="project")
g4.set(ylim=(0, 0.6))

mozilla_data_evaluation.threshold = mozilla_data_evaluation['threshold'].astype(str)
mozilla_data_evaluation.terms = mozilla_data_evaluation['terms'].astype(str)
g5 = sns.catplot(data=mozilla_data_evaluation, x="threshold", y="balanced_acc"
                , hue="terms", kind="point", height=6
                , aspect=2, order=['24', '188', '278', '365']
                , col="project")
g5.set(ylim=(0, 0.6))

winehq_data_evaluation.threshold = winehq_data_evaluation['threshold'].astype(str)
winehq_data_evaluation.terms = winehq_data_evaluation['terms'].astype(str)
g6 = sns.catplot(data=winehq_data_evaluation, x="threshold", y="balanced_acc"
                , hue="terms", kind="point", height=6
                , aspect=2, order=['220', '365', '491', '798']
                , col="project")
g6.set(ylim=(0, 0.6))

sns.despine(offset=10)
